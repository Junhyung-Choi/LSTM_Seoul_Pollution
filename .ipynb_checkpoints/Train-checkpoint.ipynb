# %%
# import library for data processing
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# read original pollution.csv file
df = pd.read_csv('data/pollution.csv')
df.head()
# Out:
#    Measurement date  Station code  \
# 0  2017-01-01 00:00           101
# 1  2017-01-01 01:00           101
# 2  2017-01-01 02:00           101
# 3  2017-01-01 03:00           101
# 4  2017-01-01 04:00           101
#
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
#
#      SO2    NO2     O3   CO  PM10  PM2.5
# 0  0.004  0.059  0.002  1.2  73.0   57.0
# 1  0.004  0.058  0.002  1.2  71.0   59.0
# 2  0.004  0.056  0.002  1.2  70.0   59.0
# 3  0.004  0.056  0.002  1.2  70.0   58.0
# 4  0.003  0.051  0.002  1.2  69.0   61.0

# %%
# select station 108 and reset index
condition = (df['Station code'] == 108)
df = df[condition]
df.reset_index(drop = True, inplace = True)

# %%
# drop unnecessary data column
df = df.drop(['Station code','Address','Latitude','Longitude'], axis=1)
df["Measurement date"] = pd.to_datetime(df["Measurement date"])
df.head()
# Out:
#      Measurement date    SO2    NO2     O3   CO  PM10  PM2.5
# 0 2017-01-01 00:00:00  0.004  0.045  0.003  0.8  68.0   63.0
# 1 2017-01-01 01:00:00  0.004  0.045  0.003  0.9  71.0   62.0
# 2 2017-01-01 02:00:00  0.004  0.043  0.003  0.9  69.0   62.0
# 3 2017-01-01 03:00:00  0.004  0.039  0.003  0.7  70.0   63.0
# 4 2017-01-01 04:00:00  0.004  0.038  0.003  0.8  69.0   59.0

# %%
# read weather data csv (2017, 2018, 2019) and concat
weather_df = pd.concat(
    [
        pd.concat(
            [pd.read_csv('data/2017.csv'),pd.read_csv('data/2018.csv')],
            ignore_index = True
        ),
        pd.read_csv('data/2019.csv')
    ],
    ignore_index = True
)
weather_df.tail()
weather_df = weather_df.drop(["Station code"],axis=1)
weather_df["Measurement date"] = pd.to_datetime(weather_df['Measurement date'])
weather_df.head()
# Out:
#      Measurement date  precipitation  wind_speed  wind_direction  humidity  \
# 0 2017-01-01 01:00:00            NaN         1.4            20.0      78.0
# 1 2017-01-01 02:00:00            NaN         1.9            50.0      81.0
# 2 2017-01-01 03:00:00            NaN         2.0            50.0      84.0
# 3 2017-01-01 04:00:00            NaN         1.6            20.0      85.0
# 4 2017-01-01 05:00:00            NaN         1.4            50.0      86.0
#
#    local pressure  ground_temperature
# 0          1018.9                -0.9
# 1          1018.5                -1.8
# 2          1018.8                -2.1
# 3          1018.6                -2.4
# 4          1018.3                -2.6

# %%
# merge pollution_df and weather_df, fill NaN data to zero
df = pd.merge(df,weather_df, how='left', on = 'Measurement date')
df['precipitation'] = df['precipitation'].fillna(0)
df = df.fillna(method = "bfill")
df['PM10'] = df['PM10'].replace(-1,0)
df.sort_values(by=['PM10'],ascending=False).head(150)
# Out:
#          Measurement date    SO2    NO2     O3    CO    PM10  PM2.5  \
# 4404  2017-07-03 12:00:00  0.000  0.000  0.000   0.0  1661.0    0.0
# 23718 2019-10-01 20:00:00  0.004  0.025  0.017   0.8   985.0   31.0
# 14183 2018-08-14 23:00:00  0.006  0.013  0.032   0.4   985.0   23.0
# 14635 2018-09-02 19:00:00  0.004  0.021  0.030   0.5   985.0   11.0
# 14519 2018-08-28 23:00:00  0.004  0.024  0.005   0.5   985.0    1.0
# ...                   ...    ...    ...    ...   ...     ...    ...
# 11536 2018-04-26 16:00:00  0.003  0.017  0.062   0.7   336.0  325.0
# 11057 2018-04-06 17:00:00  0.002  0.015  0.035   0.3   333.0   30.0
# 11056 2018-04-06 16:00:00  0.002  0.015  0.033   0.3   319.0   30.0
# 6856  2017-10-13 16:00:00  0.003  0.018  0.031   0.4   317.0  327.0
# 11054 2018-04-06 14:00:00  0.342  0.002  0.336  33.4   316.0   47.0
#
#        precipitation  wind_speed  wind_direction  humidity  local pressure  \
# 4404             0.0         2.9           230.0      80.0           996.1
# 23718            0.0         3.6           140.0      69.0          1007.9
# 14183            0.0         0.4             0.0      65.0           999.5
# 14635            0.0         1.5           140.0      54.0           997.4
# 14519            3.5         1.0            90.0      97.0          1000.6
# ...              ...         ...             ...       ...             ...
# 11536            0.0         2.5           200.0      23.0          1002.2
# 11057            0.0         4.4           270.0      50.0          1000.5
# 11056            0.0         4.0           270.0      50.0          1000.9
# 6856             0.0         4.7           290.0      35.0          1011.0
# 11054            0.0         3.5           270.0      56.0          1000.8
#
#        ground_temperature
# 4404                 29.5
# 23718                24.5
# 14183                28.5
# 14635                27.7
# 14519                22.7
# ...                   ...
# 11536                31.3
# 11057                 9.3
# 11056                10.4
# 6856                 18.2
# 11054                12.3
#
# [150 rows x 13 columns]

# %%
# show wind_direction bar grapgh
# Wind Direction : The 16 Cardinal Points - map to degree(0~360)
df.groupby('wind_direction').size().plot(kind='bar')
plt.show()

# %%
df['PM10'].value_counts(sort=True,dropna = False).plot(kind='barh')
sns.displot(df['PM10'])

# %%
# Processing PM10 data for training and prediction, assign variable counts and index. Then make lists to process.
value_cnts = df['PM10'].value_counts(sort=True,dropna = False).tolist()
value_cnts_index = df['PM10'].value_counts(sort=True,dropna = False).index.tolist()

good_list = []
normal_list = []
bad_list = []
verybad_list = []

# Classify 'PM10' data.
# ~30 : good
# 30~80 : normal
# 80~150 : bad
# 150~ : very bad
for i in range(len(value_cnts)):
    if value_cnts[i] <= 30:
        good_list.append(value_cnts_index[i])
    elif value_cnts[i] <= 80:
        normal_list.append(value_cnts_index[i])
    elif value_cnts[i] <= 150:
        bad_list.append(value_cnts_index[i])
    else:
        verybad_list.append(value_cnts_index[i])
    
# A name corresponding to the classified data according to the reference value is given.
def giveGroup(value):
    if value in good_list:
        return "GOOD"
    elif value in normal_list:
        return "NORMAL"
    elif value in bad_list:
        return "BAD"
    elif value in verybad_list:
        return "VERY BAD"

df['PM10'] = df.apply(lambda x: giveGroup(x['PM10']),axis = 1)

df.to_csv("show.csv", index = False)

df['PM10'].value_counts(sort=True,dropna = False).plot(kind='barh')

print(df[(df['PM10'] == "GOOD")].value_counts())
plt.show()
# Out:
# Measurement date     SO2    NO2    O3     CO   PM10  PM2.5  precipitation  wind_speed  wind_direction  humidity  local pressure  ground_temperature
# 2017-01-02 14:00:00  0.007  0.036  0.041  0.9  GOOD  100.0  0.0            3.1         200.0           59.0      1010.2           15.2                 1
# 2019-02-05 19:00:00  0.004  0.062  0.001  0.9  GOOD  32.0   0.0            0.0         0.0             28.0      1007.8           0.0                  1
# 2019-02-04 00:00:00  0.004  0.015  0.027  0.9  GOOD  79.0   0.0            2.2         250.0           86.0      1007.8           0.2                  1
# 2019-02-04 01:00:00  0.004  0.013  0.029  0.8  GOOD  73.0   0.0            3.2         290.0           55.0      1009.4           0.0                  1
# 2019-02-04 02:00:00  0.004  0.016  0.026  0.8  GOOD  66.0   0.0            2.7         320.0           51.0      1010.7          -0.1                  1
#                                                                                                                                                       ..
# 2018-01-18 06:00:00  0.003  0.045  0.016  0.9  GOOD  74.0   0.0            2.0         290.0           82.0      1010.5           0.0                  1
# 2018-01-18 07:00:00  0.003  0.059  0.005  1.0  GOOD  73.0   0.0            1.1         290.0           86.0      1011.2          -0.1                  1
# 2018-01-18 08:00:00  0.003  0.060  0.004  1.0  GOOD  69.0   0.0            1.2         290.0           86.0      1011.0          -0.1                  1
# 2018-01-18 10:00:00  0.004  0.051  0.010  1.0  GOOD  60.0   0.0            2.1         320.0           81.0      1013.0           0.0                  1
# 2019-12-11 11:00:00  0.004  0.024  0.031  0.9  GOOD  68.0   0.0            4.4         270.0           65.0      1005.7           7.5                  1
# Length: 875, dtype: int64

# %%
sampling_list = ["VERY BAD", "BAD", "NORMAL"]

new_df = df[df['PM10'] == "GOOD"]

good_count = len(new_df)

for class_name in sampling_list:
    class_index = df[df['PM10'] == class_name].index
    under_sample_index = np.random.choice(class_index, good_count, replace = False)
    under_sample = df.loc[under_sample_index]
    new_df = new_df.append(under_sample)

new_df = new_df.sample(frac=1).reset_index(drop=True)

new_df['PM10'].value_counts(sort=True, dropna=False).plot(kind = "barh")
plt.show()

# %%
from numpy import array
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras import backend as K

classes = ["GOOD","NORMAL","BAD","VERY BAD"]

temp_dict = {}
for c in classes:
    temp_dict[c] = new_df[new_df['PM10'] == c]


train_set = []
val_set = []
test_set = []

for c in classes:
    train = temp_dict[c].sample(frac = 0.8)
    temp_dict[c] = temp_dict[c].drop(train.index)

    validation = temp_dict[c].sample(frac = 0.5)
    temp_dict[c] = temp_dict[c].drop(validation.index)

    train_set.append(train)
    val_set.append(validation)
    test_set.append(temp_dict[c])

# %%
train_df = train_set[0]
val_df = val_set[0]
test_df = test_set[0]

for i in range(1,len(train_set)):
    train_df = train_df.append(train_set[i])
    val_df = val_df.append(val_set[i])
    test_df = test_df.append(test_set[i])

train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)


tr_x = train_df.drop(columns = 'PM10')
tr_y = train_df['PM10']

val_x = val_df.drop(columns = 'PM10')
val_y = val_df['PM10']

test_x = test_df.drop(columns = 'PM10')
test_y = test_df['PM10']

tr_x
# Out:
#         Measurement date    SO2    NO2     O3   CO  PM2.5  precipitation  \
# 0    2017-12-30 23:00:00  0.005  0.065  0.003  1.2  101.0            0.0
# 1    2017-05-09 08:00:00  0.006  0.040  0.014  0.5   27.0            0.0
# 2    2018-03-12 15:00:00  0.007  0.044  0.047  1.0   85.0            0.0
# 3    2019-04-05 15:00:00  0.004  0.018  0.041  0.6   17.0            0.0
# 4    2017-12-30 13:00:00  0.005  0.050  0.015  0.9   99.0            0.0
# ...                  ...    ...    ...    ...  ...    ...            ...
# 2795 2019-04-04 06:00:00  0.004  0.050  0.002  0.7   32.0            0.0
# 2796 2018-02-03 23:00:00  0.004  0.017  0.026  0.4   16.0            0.0
# 2797 2018-10-25 09:00:00  0.006  0.028  0.008  0.5   14.0            0.0
# 2798 2019-06-17 16:00:00  0.003  0.016  0.046  0.5   14.0            0.0
# 2799 2019-01-02 06:00:00  0.004  0.047  0.001  1.2   21.0            0.0
#
#       wind_speed  wind_direction  humidity  local pressure  ground_temperature
# 0            1.9           290.0      92.0          1011.2                 0.0
# 1            0.5           230.0      54.0          1004.4                16.7
# 2            2.9           250.0      32.0          1010.3                17.8
# 3            3.8           250.0      19.0           997.3                31.0
# 4            1.0            20.0      62.0          1013.6                 1.4
# ...          ...             ...       ...             ...                 ...
# 2795         0.7           160.0      69.0          1010.6                 1.3
# 2796         2.6           270.0      48.0          1017.8                -8.3
# 2797         1.0            70.0      64.0          1012.8                11.3
# 2798         3.9           290.0      41.0          1001.6                44.3
# 2799         0.6           270.0      57.0          1023.3                -9.3
#
# [2800 rows x 12 columns]

# %%
Nin = 12
Nh_l = [64,128]
Nout = 4

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def scheduler(epoch, lr):
    if epoch == 150:
        return lr * 0.1
    else:
        return lr

class LSTMModel(Sequential):
    def __init__(self, Nin, Nh_l, Nout):

        x = Input(shape=(Nin,))
        h = LSTM(Nh_l[0], activation='relu')(x)
        h = LSTM(Nh_l[1], activation='relu')(h)
        h = LSTM(Nh_l[1], activation='relu')(h)
        h = LSTM(Nh_l[0], activation='relu')(h)
        y = LSTM(Nh_l[0], activation='softmax')(h)

        super().__init__(x,y)

        self.compile(loss = root_mean_squared_error, optimizer='adam',
                     metrics = tf.keras.metrics.RootMeanSqaureError())
    
def train():
    model = LSTMModel(Nin,Nh_l, Nout)

    history = model.fit(tr_x, tr_y, epoch=300, batch_size=32, validation_data = (val_x, val_y))

    model.summary()
    model.save_weights("./models/weight_final.h5")

train()
# Out:
# 2021-12-17 04:03:14.512031: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: UNKNOWN ERROR (100)
# 2021-12-17 04:03:14.512150: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (JunhyungChoi-PC): /proc/driver/nvidia/version does not exist
# 2021-12-17 04:03:14.513144: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_499/239121860.py in <module>
#      35     model.save_weights("./models/weight_final.h5")
#      36
# ---> 37 train()
#
# /tmp/ipykernel_499/239121860.py in train()
#      28
#      29 def train():
# ---> 30     model = LSTMModel(Nin,Nh_l, Nout)
#      31
#      32     history = model.fit(tr_x, tr_y, epoch=300, batch_size=32, validation_data = (val_x, val_y))
#
# /tmp/ipykernel_499/239121860.py in __init__(self, Nin, Nh_l, Nout)
#      16
#      17         x = Input(shape=(Nin,))
# ---> 18         h = LSTM(Nh_l[0], activation='relu')(x)
#      19         h = LSTM(Nh_l[1], activation='relu')(h)
#      20         h = LSTM(Nh_l[1], activation='relu')(h)
#
# ~/Sophomore/AI/miniconda3/envs/style-transfer/lib/python3.9/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     677
#     678     if initial_state is None and constants is None:
# --> 679       return super(RNN, self).__call__(inputs, **kwargs)
#     680
#     681     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/Sophomore/AI/miniconda3/envs/style-transfer/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/Sophomore/AI/miniconda3/envs/style-transfer/lib/python3.9/site-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     211       ndim = shape.rank
#     212       if ndim != spec.ndim:
# --> 213         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#     214                          'is incompatible with the layer: '
#     215                          f'expected ndim={spec.ndim}, found ndim={ndim}. '
#
# ValueError: Input 0 of layer "lstm" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 12)
